# %% [markdown]
# <a href="https://colab.research.google.com/github/KollexTheAnalyst/Electricity-Forecast/blob/main/Combined_Model_GRU2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## load data----
## Temperature values, transformed temperature values in heating and cooling days and seasonal regressors
## (months, days) are already provided. Detailed information can be found in the associated study.

MT_deterministic_data <- read.csv("mid_deterministic_data.csv")

# %%
# make a training set until end of 2018
mid_training = MT_deterministic_data[1:2190,]

# %%
##Load Trimmed result from Linear regressor model

combination_mid_final <- read.csv("midterm_combinations_final_trimmed.csv")

# %%
variables_mid <- colnames(combination_mid_final[4,2:22])[complete.cases(t(combination_mid_final[4,2:22]))]

# %%
## add month variables step-wise
variables_midterm_month=colnames(MT_deterministic_data[,c(18:28)])

# %%
month_formula <- as.formula(paste("mid_load", paste(variables_midterm_month, collapse = " + "),
                               sep = " ~ "))

# %%
model_month <- lm(month_formula, data= mid_training,na.action="na.fail")

# %%
# Install the MuMIn package
install.packages("MuMIn")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘insight’

# %%
# Load the MuMIn package
library(MuMIn)

# %%
# dredge() method is just a quick way to get the logical matrix, should go very fast
combinations_month <- dredge(model_month,trace = T)
# Out:
# Fixed term is "(Intercept)"
# 0 : lm(formula = mid_load ~ 1, data = mid_training, na.action = "na.fail")
# 1 : lm(formula = mid_load ~ apr + 1, data = mid_training, na.action = "na.fail")
# 2 : lm(formula = mid_load ~ aug + 1, data = mid_training, na.action = "na.fail")
# 3 : lm(formula = mid_load ~ apr + aug + 1, data = mid_training, na.action = "na.fail")
# 4 : lm(formula = mid_load ~ feb + 1, data = mid_training, na.action = "na.fail")
# 5 : lm(formula = mid_load ~ apr + feb + 1, data = mid_training, na.action = "na.fail")
# 6 : lm(formula = mid_load ~ aug + feb + 1, data = mid_training, na.action = "na.fail")
# 7 : lm(formula = mid_load ~ apr + aug + feb + 1, data = mid_training,
#     na.action = "na.fail")
# 8 : lm(formula = mid_load ~ jan + 1, data = mid_training, na.action = "na.fail")
# 9 : lm(formula = mid_load ~ apr + jan + 1, data = mid_training, na.action = "na.fail")
# 10 : lm(formula = mid_load ~ aug + jan + 1, data = mid_training, na.action = "na.fail")
# 11 : lm(formula = mid_load ~ apr + aug + jan + 1, data = mid_training,
#     na.action = "na.fail")
# 12 : lm(formula = mid_load ~ feb + jan + 1, data = mid_training, na.action = "na.fail")
# 13 : lm(formula = mid_load ~ apr + feb + jan + 1, data = mid_training,
#     na.action = "na.fail")
# 14 : lm(formula = mid_load ~ aug + feb + jan + 1, data = mid_training,
#     na.action = "na.fail")
# 15 : lm(formula = mid_load ~ apr + aug + feb + jan + 1, data = mid_training,
#     na.action = "na.fail")
# 16 : lm(formula = mid_load ~ jul + 1, data = mid_training, na.action = "na.fail")
# 17 : lm(formula = mid_load ~ apr + jul + 1, data = mid_training, na.action = "na.fail")
# 18 : lm(formula = mid_load ~ aug + jul + 1, data = mid_training, na.action = "na.fail")
# 19 : lm(formula = mid_load ~ apr + aug + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 20 : lm(formula = mid_load ~ feb + jul + 1, data = mid_training, na.action = "na.fail")
# 21 : lm(formula = mid_load ~ apr + feb + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 22 : lm(formula = mid_load ~ aug + feb + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 23 : lm(formula = mid_load ~ apr + aug + feb + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 24 : lm(formula = mid_load ~ jan + jul + 1, data = mid_training, na.action = "na.fail")
# 25 : lm(formula = mid_load ~ apr + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 26 : lm(formula = mid_load ~ aug + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 27 : lm(formula = mid_load ~ apr + aug + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 28 : lm(formula = mid_load ~ feb + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 29 : lm(formula = mid_load ~ apr + feb + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 30 : lm(formula = mid_load ~ aug + feb + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 31 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + 1, data = mid_training,
#     na.action = "na.fail")
# 32 : lm(formula = mid_load ~ jun + 1, data = mid_training, na.action = "na.fail")
# 33 : lm(formula = mid_load ~ apr + jun + 1, data = mid_training, na.action = "na.fail")
# 34 : lm(formula = mid_load ~ aug + jun + 1, data = mid_training, na.action = "na.fail")
# 35 : lm(formula = mid_load ~ apr + aug + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 36 : lm(formula = mid_load ~ feb + jun + 1, data = mid_training, na.action = "na.fail")
# 37 : lm(formula = mid_load ~ apr + feb + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 38 : lm(formula = mid_load ~ aug + feb + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 39 : lm(formula = mid_load ~ apr + aug + feb + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 40 : lm(formula = mid_load ~ jan + jun + 1, data = mid_training, na.action = "na.fail")
# 41 : lm(formula = mid_load ~ apr + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 42 : lm(formula = mid_load ~ aug + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 43 : lm(formula = mid_load ~ apr + aug + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 44 : lm(formula = mid_load ~ feb + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 45 : lm(formula = mid_load ~ apr + feb + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 46 : lm(formula = mid_load ~ aug + feb + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 47 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 48 : lm(formula = mid_load ~ jul + jun + 1, data = mid_training, na.action = "na.fail")
# 49 : lm(formula = mid_load ~ apr + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 50 : lm(formula = mid_load ~ aug + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 51 : lm(formula = mid_load ~ apr + aug + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 52 : lm(formula = mid_load ~ feb + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 53 : lm(formula = mid_load ~ apr + feb + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 54 : lm(formula = mid_load ~ aug + feb + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 55 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 56 : lm(formula = mid_load ~ jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 57 : lm(formula = mid_load ~ apr + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 58 : lm(formula = mid_load ~ aug + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 59 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 60 : lm(formula = mid_load ~ feb + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 61 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 62 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + 1, data = mid_training,
#     na.action = "na.fail")
# 63 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + 1,
#     data = mid_training, na.action = "na.fail")
# 64 : lm(formula = mid_load ~ mai + 1, data = mid_training, na.action = "na.fail")
# 65 : lm(formula = mid_load ~ apr + mai + 1, data = mid_training, na.action = "na.fail")
# 66 : lm(formula = mid_load ~ aug + mai + 1, data = mid_training, na.action = "na.fail")
# 67 : lm(formula = mid_load ~ apr + aug + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 68 : lm(formula = mid_load ~ feb + mai + 1, data = mid_training, na.action = "na.fail")
# 69 : lm(formula = mid_load ~ apr + feb + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 70 : lm(formula = mid_load ~ aug + feb + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 71 : lm(formula = mid_load ~ apr + aug + feb + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 72 : lm(formula = mid_load ~ jan + mai + 1, data = mid_training, na.action = "na.fail")
# 73 : lm(formula = mid_load ~ apr + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 74 : lm(formula = mid_load ~ aug + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 75 : lm(formula = mid_load ~ apr + aug + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 76 : lm(formula = mid_load ~ feb + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 77 : lm(formula = mid_load ~ apr + feb + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 78 : lm(formula = mid_load ~ aug + feb + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 79 : lm(formula = mid_load ~ apr + aug + feb + jan + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 80 : lm(formula = mid_load ~ jul + mai + 1, data = mid_training, na.action = "na.fail")
# 81 : lm(formula = mid_load ~ apr + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 82 : lm(formula = mid_load ~ aug + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 83 : lm(formula = mid_load ~ apr + aug + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 84 : lm(formula = mid_load ~ feb + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 85 : lm(formula = mid_load ~ apr + feb + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 86 : lm(formula = mid_load ~ aug + feb + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 87 : lm(formula = mid_load ~ apr + aug + feb + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 88 : lm(formula = mid_load ~ jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 89 : lm(formula = mid_load ~ apr + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 90 : lm(formula = mid_load ~ aug + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 91 : lm(formula = mid_load ~ apr + aug + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 92 : lm(formula = mid_load ~ feb + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 93 : lm(formula = mid_load ~ apr + feb + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 94 : lm(formula = mid_load ~ aug + feb + jan + jul + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 95 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 96 : lm(formula = mid_load ~ jun + mai + 1, data = mid_training, na.action = "na.fail")
# 97 : lm(formula = mid_load ~ apr + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 98 : lm(formula = mid_load ~ aug + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 99 : lm(formula = mid_load ~ apr + aug + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 100 : lm(formula = mid_load ~ feb + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 101 : lm(formula = mid_load ~ apr + feb + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 102 : lm(formula = mid_load ~ aug + feb + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 103 : lm(formula = mid_load ~ apr + aug + feb + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 104 : lm(formula = mid_load ~ jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 105 : lm(formula = mid_load ~ apr + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 106 : lm(formula = mid_load ~ aug + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 107 : lm(formula = mid_load ~ apr + aug + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 108 : lm(formula = mid_load ~ feb + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 109 : lm(formula = mid_load ~ apr + feb + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 110 : lm(formula = mid_load ~ aug + feb + jan + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 111 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 112 : lm(formula = mid_load ~ jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 113 : lm(formula = mid_load ~ apr + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 114 : lm(formula = mid_load ~ aug + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 115 : lm(formula = mid_load ~ apr + aug + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 116 : lm(formula = mid_load ~ feb + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 117 : lm(formula = mid_load ~ apr + feb + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 118 : lm(formula = mid_load ~ aug + feb + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 119 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 120 : lm(formula = mid_load ~ jan + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 121 : lm(formula = mid_load ~ apr + jan + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 122 : lm(formula = mid_load ~ aug + jan + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 123 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 124 : lm(formula = mid_load ~ feb + jan + jul + jun + mai + 1, data = mid_training,
#     na.action = "na.fail")
# 125 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 126 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mai + 1,
#     data = mid_training, na.action = "na.fail")
# 127 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mai +
#     1, data = mid_training, na.action = "na.fail")
# 128 : lm(formula = mid_load ~ mar + 1, data = mid_training, na.action = "na.fail")
# 129 : lm(formula = mid_load ~ apr + mar + 1, data = mid_training, na.action = "na.fail")
# 130 : lm(formula = mid_load ~ aug + mar + 1, data = mid_training, na.action = "na.fail")
# 131 : lm(formula = mid_load ~ apr + aug + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 132 : lm(formula = mid_load ~ feb + mar + 1, data = mid_training, na.action = "na.fail")
# 133 : lm(formula = mid_load ~ apr + feb + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 134 : lm(formula = mid_load ~ aug + feb + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 135 : lm(formula = mid_load ~ apr + aug + feb + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 136 : lm(formula = mid_load ~ jan + mar + 1, data = mid_training, na.action = "na.fail")
# 137 : lm(formula = mid_load ~ apr + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 138 : lm(formula = mid_load ~ aug + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 139 : lm(formula = mid_load ~ apr + aug + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 140 : lm(formula = mid_load ~ feb + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 141 : lm(formula = mid_load ~ apr + feb + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 142 : lm(formula = mid_load ~ aug + feb + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 143 : lm(formula = mid_load ~ apr + aug + feb + jan + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 144 : lm(formula = mid_load ~ jul + mar + 1, data = mid_training, na.action = "na.fail")
# 145 : lm(formula = mid_load ~ apr + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 146 : lm(formula = mid_load ~ aug + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 147 : lm(formula = mid_load ~ apr + aug + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 148 : lm(formula = mid_load ~ feb + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 149 : lm(formula = mid_load ~ apr + feb + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 150 : lm(formula = mid_load ~ aug + feb + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 151 : lm(formula = mid_load ~ apr + aug + feb + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 152 : lm(formula = mid_load ~ jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 153 : lm(formula = mid_load ~ apr + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 154 : lm(formula = mid_load ~ aug + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 155 : lm(formula = mid_load ~ apr + aug + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 156 : lm(formula = mid_load ~ feb + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 157 : lm(formula = mid_load ~ apr + feb + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 158 : lm(formula = mid_load ~ aug + feb + jan + jul + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 159 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 160 : lm(formula = mid_load ~ jun + mar + 1, data = mid_training, na.action = "na.fail")
# 161 : lm(formula = mid_load ~ apr + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 162 : lm(formula = mid_load ~ aug + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 163 : lm(formula = mid_load ~ apr + aug + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 164 : lm(formula = mid_load ~ feb + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 165 : lm(formula = mid_load ~ apr + feb + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 166 : lm(formula = mid_load ~ aug + feb + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 167 : lm(formula = mid_load ~ apr + aug + feb + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 168 : lm(formula = mid_load ~ jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 169 : lm(formula = mid_load ~ apr + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 170 : lm(formula = mid_load ~ aug + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 171 : lm(formula = mid_load ~ apr + aug + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 172 : lm(formula = mid_load ~ feb + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 173 : lm(formula = mid_load ~ apr + feb + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 174 : lm(formula = mid_load ~ aug + feb + jan + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 175 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 176 : lm(formula = mid_load ~ jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 177 : lm(formula = mid_load ~ apr + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 178 : lm(formula = mid_load ~ aug + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 179 : lm(formula = mid_load ~ apr + aug + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 180 : lm(formula = mid_load ~ feb + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 181 : lm(formula = mid_load ~ apr + feb + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 182 : lm(formula = mid_load ~ aug + feb + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 183 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 184 : lm(formula = mid_load ~ jan + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 185 : lm(formula = mid_load ~ apr + jan + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 186 : lm(formula = mid_load ~ aug + jan + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 187 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 188 : lm(formula = mid_load ~ feb + jan + jul + jun + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 189 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 190 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 191 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mar +
#     1, data = mid_training, na.action = "na.fail")
# 192 : lm(formula = mid_load ~ mai + mar + 1, data = mid_training, na.action = "na.fail")
# 193 : lm(formula = mid_load ~ apr + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 194 : lm(formula = mid_load ~ aug + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 195 : lm(formula = mid_load ~ apr + aug + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 196 : lm(formula = mid_load ~ feb + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 197 : lm(formula = mid_load ~ apr + feb + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 198 : lm(formula = mid_load ~ aug + feb + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 199 : lm(formula = mid_load ~ apr + aug + feb + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 200 : lm(formula = mid_load ~ jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 201 : lm(formula = mid_load ~ apr + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 202 : lm(formula = mid_load ~ aug + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 203 : lm(formula = mid_load ~ apr + aug + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 204 : lm(formula = mid_load ~ feb + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 205 : lm(formula = mid_load ~ apr + feb + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 206 : lm(formula = mid_load ~ aug + feb + jan + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 207 : lm(formula = mid_load ~ apr + aug + feb + jan + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 208 : lm(formula = mid_load ~ jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 209 : lm(formula = mid_load ~ apr + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 210 : lm(formula = mid_load ~ aug + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 211 : lm(formula = mid_load ~ apr + aug + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 212 : lm(formula = mid_load ~ feb + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 213 : lm(formula = mid_load ~ apr + feb + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 214 : lm(formula = mid_load ~ aug + feb + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 215 : lm(formula = mid_load ~ apr + aug + feb + jul + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 216 : lm(formula = mid_load ~ jan + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 217 : lm(formula = mid_load ~ apr + jan + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 218 : lm(formula = mid_load ~ aug + jan + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 219 : lm(formula = mid_load ~ apr + aug + jan + jul + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 220 : lm(formula = mid_load ~ feb + jan + jul + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 221 : lm(formula = mid_load ~ apr + feb + jan + jul + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 222 : lm(formula = mid_load ~ aug + feb + jan + jul + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 223 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 224 : lm(formula = mid_load ~ jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 225 : lm(formula = mid_load ~ apr + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 226 : lm(formula = mid_load ~ aug + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 227 : lm(formula = mid_load ~ apr + aug + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 228 : lm(formula = mid_load ~ feb + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 229 : lm(formula = mid_load ~ apr + feb + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 230 : lm(formula = mid_load ~ aug + feb + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 231 : lm(formula = mid_load ~ apr + aug + feb + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 232 : lm(formula = mid_load ~ jan + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 233 : lm(formula = mid_load ~ apr + jan + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 234 : lm(formula = mid_load ~ aug + jan + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 235 : lm(formula = mid_load ~ apr + aug + jan + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 236 : lm(formula = mid_load ~ feb + jan + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 237 : lm(formula = mid_load ~ apr + feb + jan + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 238 : lm(formula = mid_load ~ aug + feb + jan + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 239 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 240 : lm(formula = mid_load ~ jul + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 241 : lm(formula = mid_load ~ apr + jul + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 242 : lm(formula = mid_load ~ aug + jul + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 243 : lm(formula = mid_load ~ apr + aug + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 244 : lm(formula = mid_load ~ feb + jul + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 245 : lm(formula = mid_load ~ apr + feb + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 246 : lm(formula = mid_load ~ aug + feb + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 247 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 248 : lm(formula = mid_load ~ jan + jul + jun + mai + mar + 1, data = mid_training,
#     na.action = "na.fail")
# 249 : lm(formula = mid_load ~ apr + jan + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 250 : lm(formula = mid_load ~ aug + jan + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 251 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 252 : lm(formula = mid_load ~ feb + jan + jul + jun + mai + mar + 1,
#     data = mid_training, na.action = "na.fail")
# 253 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 254 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mai + mar +
#     1, data = mid_training, na.action = "na.fail")
# 255 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mai +
#     mar + 1, data = mid_training, na.action = "na.fail")
# 256 : lm(formula = mid_load ~ nov + 1, data = mid_training, na.action = "na.fail")
# 257 : lm(formula = mid_load ~ apr + nov + 1, data = mid_training, na.action = "na.fail")
# 258 : lm(formula = mid_load ~ aug + nov + 1, data = mid_training, na.action = "na.fail")
# 259 : lm(formula = mid_load ~ apr + aug + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 260 : lm(formula = mid_load ~ feb + nov + 1, data = mid_training, na.action = "na.fail")
# 261 : lm(formula = mid_load ~ apr + feb + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 262 : lm(formula = mid_load ~ aug + feb + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 263 : lm(formula = mid_load ~ apr + aug + feb + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 264 : lm(formula = mid_load ~ jan + nov + 1, data = mid_training, na.action = "na.fail")
# 265 : lm(formula = mid_load ~ apr + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 266 : lm(formula = mid_load ~ aug + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 267 : lm(formula = mid_load ~ apr + aug + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 268 : lm(formula = mid_load ~ feb + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 269 : lm(formula = mid_load ~ apr + feb + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 270 : lm(formula = mid_load ~ aug + feb + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 271 : lm(formula = mid_load ~ apr + aug + feb + jan + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 272 : lm(formula = mid_load ~ jul + nov + 1, data = mid_training, na.action = "na.fail")
# 273 : lm(formula = mid_load ~ apr + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 274 : lm(formula = mid_load ~ aug + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 275 : lm(formula = mid_load ~ apr + aug + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 276 : lm(formula = mid_load ~ feb + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 277 : lm(formula = mid_load ~ apr + feb + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 278 : lm(formula = mid_load ~ aug + feb + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 279 : lm(formula = mid_load ~ apr + aug + feb + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 280 : lm(formula = mid_load ~ jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 281 : lm(formula = mid_load ~ apr + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 282 : lm(formula = mid_load ~ aug + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 283 : lm(formula = mid_load ~ apr + aug + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 284 : lm(formula = mid_load ~ feb + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 285 : lm(formula = mid_load ~ apr + feb + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 286 : lm(formula = mid_load ~ aug + feb + jan + jul + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 287 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 288 : lm(formula = mid_load ~ jun + nov + 1, data = mid_training, na.action = "na.fail")
# 289 : lm(formula = mid_load ~ apr + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 290 : lm(formula = mid_load ~ aug + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 291 : lm(formula = mid_load ~ apr + aug + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 292 : lm(formula = mid_load ~ feb + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 293 : lm(formula = mid_load ~ apr + feb + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 294 : lm(formula = mid_load ~ aug + feb + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 295 : lm(formula = mid_load ~ apr + aug + feb + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 296 : lm(formula = mid_load ~ jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 297 : lm(formula = mid_load ~ apr + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 298 : lm(formula = mid_load ~ aug + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 299 : lm(formula = mid_load ~ apr + aug + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 300 : lm(formula = mid_load ~ feb + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 301 : lm(formula = mid_load ~ apr + feb + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 302 : lm(formula = mid_load ~ aug + feb + jan + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 303 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 304 : lm(formula = mid_load ~ jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 305 : lm(formula = mid_load ~ apr + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 306 : lm(formula = mid_load ~ aug + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 307 : lm(formula = mid_load ~ apr + aug + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 308 : lm(formula = mid_load ~ feb + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 309 : lm(formula = mid_load ~ apr + feb + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 310 : lm(formula = mid_load ~ aug + feb + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 311 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 312 : lm(formula = mid_load ~ jan + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 313 : lm(formula = mid_load ~ apr + jan + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 314 : lm(formula = mid_load ~ aug + jan + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 315 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 316 : lm(formula = mid_load ~ feb + jan + jul + jun + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 317 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 318 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 319 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + nov +
#     1, data = mid_training, na.action = "na.fail")
# 320 : lm(formula = mid_load ~ mai + nov + 1, data = mid_training, na.action = "na.fail")
# 321 : lm(formula = mid_load ~ apr + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 322 : lm(formula = mid_load ~ aug + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 323 : lm(formula = mid_load ~ apr + aug + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 324 : lm(formula = mid_load ~ feb + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 325 : lm(formula = mid_load ~ apr + feb + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 326 : lm(formula = mid_load ~ aug + feb + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 327 : lm(formula = mid_load ~ apr + aug + feb + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 328 : lm(formula = mid_load ~ jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 329 : lm(formula = mid_load ~ apr + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 330 : lm(formula = mid_load ~ aug + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 331 : lm(formula = mid_load ~ apr + aug + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 332 : lm(formula = mid_load ~ feb + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 333 : lm(formula = mid_load ~ apr + feb + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 334 : lm(formula = mid_load ~ aug + feb + jan + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 335 : lm(formula = mid_load ~ apr + aug + feb + jan + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 336 : lm(formula = mid_load ~ jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 337 : lm(formula = mid_load ~ apr + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 338 : lm(formula = mid_load ~ aug + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 339 : lm(formula = mid_load ~ apr + aug + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 340 : lm(formula = mid_load ~ feb + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 341 : lm(formula = mid_load ~ apr + feb + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 342 : lm(formula = mid_load ~ aug + feb + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 343 : lm(formula = mid_load ~ apr + aug + feb + jul + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 344 : lm(formula = mid_load ~ jan + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 345 : lm(formula = mid_load ~ apr + jan + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 346 : lm(formula = mid_load ~ aug + jan + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 347 : lm(formula = mid_load ~ apr + aug + jan + jul + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 348 : lm(formula = mid_load ~ feb + jan + jul + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 349 : lm(formula = mid_load ~ apr + feb + jan + jul + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 350 : lm(formula = mid_load ~ aug + feb + jan + jul + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 351 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 352 : lm(formula = mid_load ~ jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 353 : lm(formula = mid_load ~ apr + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 354 : lm(formula = mid_load ~ aug + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 355 : lm(formula = mid_load ~ apr + aug + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 356 : lm(formula = mid_load ~ feb + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 357 : lm(formula = mid_load ~ apr + feb + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 358 : lm(formula = mid_load ~ aug + feb + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 359 : lm(formula = mid_load ~ apr + aug + feb + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 360 : lm(formula = mid_load ~ jan + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 361 : lm(formula = mid_load ~ apr + jan + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 362 : lm(formula = mid_load ~ aug + jan + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 363 : lm(formula = mid_load ~ apr + aug + jan + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 364 : lm(formula = mid_load ~ feb + jan + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 365 : lm(formula = mid_load ~ apr + feb + jan + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 366 : lm(formula = mid_load ~ aug + feb + jan + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 367 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 368 : lm(formula = mid_load ~ jul + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 369 : lm(formula = mid_load ~ apr + jul + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 370 : lm(formula = mid_load ~ aug + jul + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 371 : lm(formula = mid_load ~ apr + aug + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 372 : lm(formula = mid_load ~ feb + jul + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 373 : lm(formula = mid_load ~ apr + feb + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 374 : lm(formula = mid_load ~ aug + feb + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 375 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 376 : lm(formula = mid_load ~ jan + jul + jun + mai + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 377 : lm(formula = mid_load ~ apr + jan + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 378 : lm(formula = mid_load ~ aug + jan + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 379 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 380 : lm(formula = mid_load ~ feb + jan + jul + jun + mai + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 381 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 382 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mai + nov +
#     1, data = mid_training, na.action = "na.fail")
# 383 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mai +
#     nov + 1, data = mid_training, na.action = "na.fail")
# 384 : lm(formula = mid_load ~ mar + nov + 1, data = mid_training, na.action = "na.fail")
# 385 : lm(formula = mid_load ~ apr + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 386 : lm(formula = mid_load ~ aug + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 387 : lm(formula = mid_load ~ apr + aug + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 388 : lm(formula = mid_load ~ feb + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 389 : lm(formula = mid_load ~ apr + feb + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 390 : lm(formula = mid_load ~ aug + feb + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 391 : lm(formula = mid_load ~ apr + aug + feb + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 392 : lm(formula = mid_load ~ jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 393 : lm(formula = mid_load ~ apr + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 394 : lm(formula = mid_load ~ aug + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 395 : lm(formula = mid_load ~ apr + aug + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 396 : lm(formula = mid_load ~ feb + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 397 : lm(formula = mid_load ~ apr + feb + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 398 : lm(formula = mid_load ~ aug + feb + jan + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 399 : lm(formula = mid_load ~ apr + aug + feb + jan + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 400 : lm(formula = mid_load ~ jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 401 : lm(formula = mid_load ~ apr + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 402 : lm(formula = mid_load ~ aug + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 403 : lm(formula = mid_load ~ apr + aug + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 404 : lm(formula = mid_load ~ feb + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 405 : lm(formula = mid_load ~ apr + feb + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 406 : lm(formula = mid_load ~ aug + feb + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 407 : lm(formula = mid_load ~ apr + aug + feb + jul + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 408 : lm(formula = mid_load ~ jan + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 409 : lm(formula = mid_load ~ apr + jan + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 410 : lm(formula = mid_load ~ aug + jan + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 411 : lm(formula = mid_load ~ apr + aug + jan + jul + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 412 : lm(formula = mid_load ~ feb + jan + jul + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 413 : lm(formula = mid_load ~ apr + feb + jan + jul + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 414 : lm(formula = mid_load ~ aug + feb + jan + jul + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 415 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 416 : lm(formula = mid_load ~ jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 417 : lm(formula = mid_load ~ apr + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 418 : lm(formula = mid_load ~ aug + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 419 : lm(formula = mid_load ~ apr + aug + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 420 : lm(formula = mid_load ~ feb + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 421 : lm(formula = mid_load ~ apr + feb + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 422 : lm(formula = mid_load ~ aug + feb + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 423 : lm(formula = mid_load ~ apr + aug + feb + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 424 : lm(formula = mid_load ~ jan + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 425 : lm(formula = mid_load ~ apr + jan + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 426 : lm(formula = mid_load ~ aug + jan + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 427 : lm(formula = mid_load ~ apr + aug + jan + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 428 : lm(formula = mid_load ~ feb + jan + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 429 : lm(formula = mid_load ~ apr + feb + jan + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 430 : lm(formula = mid_load ~ aug + feb + jan + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 431 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 432 : lm(formula = mid_load ~ jul + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 433 : lm(formula = mid_load ~ apr + jul + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 434 : lm(formula = mid_load ~ aug + jul + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 435 : lm(formula = mid_load ~ apr + aug + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 436 : lm(formula = mid_load ~ feb + jul + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 437 : lm(formula = mid_load ~ apr + feb + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 438 : lm(formula = mid_load ~ aug + feb + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 439 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 440 : lm(formula = mid_load ~ jan + jul + jun + mar + nov + 1, data = mid_training,
#     na.action = "na.fail")
# 441 : lm(formula = mid_load ~ apr + jan + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 442 : lm(formula = mid_load ~ aug + jan + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 443 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 444 : lm(formula = mid_load ~ feb + jan + jul + jun + mar + nov + 1,
#     data = mid_training, na.action = "na.fail")
# 445 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 446 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mar + nov +
#     1, data = mid_training, na.action = "na.fail")
# 447 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mar +
#     nov + 1, data = mid_training, na.action = "na.fail")
# ...
#     data = mid_training, na.action = "na.fail")
# 1924 : lm(formula = mid_load ~ feb + mar + nov + okt + sep + 1, data = mid_training,
#     na.action = "na.fail")
# 1925 : lm(formula = mid_load ~ apr + feb + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1926 : lm(formula = mid_load ~ aug + feb + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1927 : lm(formula = mid_load ~ apr + aug + feb + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1928 : lm(formula = mid_load ~ jan + mar + nov + okt + sep + 1, data = mid_training,
#     na.action = "na.fail")
# 1929 : lm(formula = mid_load ~ apr + jan + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1930 : lm(formula = mid_load ~ aug + jan + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1931 : lm(formula = mid_load ~ apr + aug + jan + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1932 : lm(formula = mid_load ~ feb + jan + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1933 : lm(formula = mid_load ~ apr + feb + jan + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1934 : lm(formula = mid_load ~ aug + feb + jan + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1935 : lm(formula = mid_load ~ apr + aug + feb + jan + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1936 : lm(formula = mid_load ~ jul + mar + nov + okt + sep + 1, data = mid_training,
#     na.action = "na.fail")
# 1937 : lm(formula = mid_load ~ apr + jul + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1938 : lm(formula = mid_load ~ aug + jul + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1939 : lm(formula = mid_load ~ apr + aug + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1940 : lm(formula = mid_load ~ feb + jul + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1941 : lm(formula = mid_load ~ apr + feb + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1942 : lm(formula = mid_load ~ aug + feb + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1943 : lm(formula = mid_load ~ apr + aug + feb + jul + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1944 : lm(formula = mid_load ~ jan + jul + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1945 : lm(formula = mid_load ~ apr + jan + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1946 : lm(formula = mid_load ~ aug + jan + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1947 : lm(formula = mid_load ~ apr + aug + jan + jul + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1948 : lm(formula = mid_load ~ feb + jan + jul + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1949 : lm(formula = mid_load ~ apr + feb + jan + jul + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1950 : lm(formula = mid_load ~ aug + feb + jan + jul + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1951 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1952 : lm(formula = mid_load ~ jun + mar + nov + okt + sep + 1, data = mid_training,
#     na.action = "na.fail")
# 1953 : lm(formula = mid_load ~ apr + jun + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1954 : lm(formula = mid_load ~ aug + jun + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1955 : lm(formula = mid_load ~ apr + aug + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1956 : lm(formula = mid_load ~ feb + jun + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1957 : lm(formula = mid_load ~ apr + feb + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1958 : lm(formula = mid_load ~ aug + feb + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1959 : lm(formula = mid_load ~ apr + aug + feb + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1960 : lm(formula = mid_load ~ jan + jun + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1961 : lm(formula = mid_load ~ apr + jan + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1962 : lm(formula = mid_load ~ aug + jan + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1963 : lm(formula = mid_load ~ apr + aug + jan + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1964 : lm(formula = mid_load ~ feb + jan + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1965 : lm(formula = mid_load ~ apr + feb + jan + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1966 : lm(formula = mid_load ~ aug + feb + jan + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1967 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1968 : lm(formula = mid_load ~ jul + jun + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1969 : lm(formula = mid_load ~ apr + jul + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1970 : lm(formula = mid_load ~ aug + jul + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1971 : lm(formula = mid_load ~ apr + aug + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1972 : lm(formula = mid_load ~ feb + jul + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1973 : lm(formula = mid_load ~ apr + feb + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1974 : lm(formula = mid_load ~ aug + feb + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1975 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1976 : lm(formula = mid_load ~ jan + jul + jun + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1977 : lm(formula = mid_load ~ apr + jan + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1978 : lm(formula = mid_load ~ aug + jan + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1979 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1980 : lm(formula = mid_load ~ feb + jan + jul + jun + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1981 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1982 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1983 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 1984 : lm(formula = mid_load ~ mai + mar + nov + okt + sep + 1, data = mid_training,
#     na.action = "na.fail")
# 1985 : lm(formula = mid_load ~ apr + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1986 : lm(formula = mid_load ~ aug + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1987 : lm(formula = mid_load ~ apr + aug + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1988 : lm(formula = mid_load ~ feb + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1989 : lm(formula = mid_load ~ apr + feb + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1990 : lm(formula = mid_load ~ aug + feb + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1991 : lm(formula = mid_load ~ apr + aug + feb + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1992 : lm(formula = mid_load ~ jan + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 1993 : lm(formula = mid_load ~ apr + jan + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1994 : lm(formula = mid_load ~ aug + jan + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1995 : lm(formula = mid_load ~ apr + aug + jan + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1996 : lm(formula = mid_load ~ feb + jan + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 1997 : lm(formula = mid_load ~ apr + feb + jan + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1998 : lm(formula = mid_load ~ aug + feb + jan + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 1999 : lm(formula = mid_load ~ apr + aug + feb + jan + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2000 : lm(formula = mid_load ~ jul + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 2001 : lm(formula = mid_load ~ apr + jul + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2002 : lm(formula = mid_load ~ aug + jul + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2003 : lm(formula = mid_load ~ apr + aug + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2004 : lm(formula = mid_load ~ feb + jul + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2005 : lm(formula = mid_load ~ apr + feb + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2006 : lm(formula = mid_load ~ aug + feb + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2007 : lm(formula = mid_load ~ apr + aug + feb + jul + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2008 : lm(formula = mid_load ~ jan + jul + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2009 : lm(formula = mid_load ~ apr + jan + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2010 : lm(formula = mid_load ~ aug + jan + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2011 : lm(formula = mid_load ~ apr + aug + jan + jul + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2012 : lm(formula = mid_load ~ feb + jan + jul + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2013 : lm(formula = mid_load ~ apr + feb + jan + jul + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2014 : lm(formula = mid_load ~ aug + feb + jan + jul + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2015 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2016 : lm(formula = mid_load ~ jun + mai + mar + nov + okt + sep + 1,
#     data = mid_training, na.action = "na.fail")
# 2017 : lm(formula = mid_load ~ apr + jun + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2018 : lm(formula = mid_load ~ aug + jun + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2019 : lm(formula = mid_load ~ apr + aug + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2020 : lm(formula = mid_load ~ feb + jun + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2021 : lm(formula = mid_load ~ apr + feb + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2022 : lm(formula = mid_load ~ aug + feb + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2023 : lm(formula = mid_load ~ apr + aug + feb + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2024 : lm(formula = mid_load ~ jan + jun + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2025 : lm(formula = mid_load ~ apr + jan + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2026 : lm(formula = mid_load ~ aug + jan + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2027 : lm(formula = mid_load ~ apr + aug + jan + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2028 : lm(formula = mid_load ~ feb + jan + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2029 : lm(formula = mid_load ~ apr + feb + jan + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2030 : lm(formula = mid_load ~ aug + feb + jan + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2031 : lm(formula = mid_load ~ apr + aug + feb + jan + jun + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2032 : lm(formula = mid_load ~ jul + jun + mai + mar + nov + okt + sep +
#     1, data = mid_training, na.action = "na.fail")
# 2033 : lm(formula = mid_load ~ apr + jul + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2034 : lm(formula = mid_load ~ aug + jul + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2035 : lm(formula = mid_load ~ apr + aug + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2036 : lm(formula = mid_load ~ feb + jul + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2037 : lm(formula = mid_load ~ apr + feb + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2038 : lm(formula = mid_load ~ aug + feb + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2039 : lm(formula = mid_load ~ apr + aug + feb + jul + jun + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2040 : lm(formula = mid_load ~ jan + jul + jun + mai + mar + nov + okt +
#     sep + 1, data = mid_training, na.action = "na.fail")
# 2041 : lm(formula = mid_load ~ apr + jan + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2042 : lm(formula = mid_load ~ aug + jan + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2043 : lm(formula = mid_load ~ apr + aug + jan + jul + jun + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2044 : lm(formula = mid_load ~ feb + jan + jul + jun + mai + mar + nov +
#     okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2045 : lm(formula = mid_load ~ apr + feb + jan + jul + jun + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2046 : lm(formula = mid_load ~ aug + feb + jan + jul + jun + mai + mar +
#     nov + okt + sep + 1, data = mid_training, na.action = "na.fail")
# 2047 : lm(formula = mid_load ~ apr + aug + feb + jan + jul + jun + mai +
#     mar + nov + okt + sep + 1, data = mid_training, na.action = "na.fail")

# %%
# initiate a data frame to save the model AICc
rank_df <- as.data.frame(matrix(nrow=nrow(combinations_month),ncol = 2))
colnames(rank_df)<- c("AICc","model_no")

# %%
# calculate all combinations with month added and save AICc

for (i in 1:nrow(combinations_month)){
variables_month=colnames(combinations_month[i,2:12])[complete.cases(t(combinations_month[i,2:12]))]
variables_all= c(variables_mid,variables_month)
formula_all <- as.formula(paste("mid_load", paste(variables_all, collapse = " + "),
                                  sep = " ~ "))
model_all <- lm(formula_all, data= mid_training,na.action="na.fail")

rank_df$AICc[i] <- AICc(model_all)
rank_df$model_no[i] <- i
}

# %%
# look at best models
best_models <- order(rank_df$AICc)

variables_best_month=colnames(combinations_month[best_models[1],2:12])[complete.cases(t(combinations_month[best_models[1],2:12]))]
variables_final= c(variables_mid,variables_best_month)
formula_final <- as.formula(paste("mid_load", paste(variables_final, collapse = " + "),
                                sep = " ~ "))
model_final <- lm(formula_final, data= mid_training,na.action="na.fail")
save(model_final,file = "model2_final_new.Rdata")

# %%
MT <- predict(model_final, MT_deterministic_data, interval = "confidence")

# %%
residuals <- MT_deterministic_data$mid_load - MT[,1]
MT_deterministic_data$target_residuals <- residuals
MT_deterministic_data$lm_pred <- MT[,1]

write.csv(MT_deterministic_data,"midterm_det_new.csv", row.names = F )

# %%
##Load Prediction results from the ML-GRU model
GRU_result2 <- read.csv("New_GRU2_result_datasets_alt.csv")

# %%
###### Load machine learning GRU results ########
## Note: Code for the LSTM is proprietary owned by the DLR Oldenburg, so only the output
## of the model can be made publicly available

MT_deterministic_data$gru <- 0
MT_deterministic_data$gru[2191:2920] <- GRU_result2$Prediction

write.csv(MT_deterministic_data, "midterm_det_new_2.csv",row.names = F)

# %%
###### ARIMA calculation ########
## Note: this takes very long and is already calculated, results are stored
##       in "./Data/mid_ARIMA_results.csv"
MT_deterministic_data1 <- read.csv("midterm_det_new_2.csv")

# %%
##To use the ARIMA funtion, we have to install;
# Install the forecast package
install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘Rcpp’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %%
# Load the forecast package
library(forecast)

library(tseries)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
res <- model_final$residuals

# %%
# Install the DHARMa package
install.packages("DHARMa")

# Load the DHARMa package
library(DHARMa)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘htmlwidgets’, ‘lazyeval’, ‘crosstalk’, ‘promises’, ‘rbibutils’, ‘httpuv’, ‘xtable’, ‘sourcetools’, ‘later’, ‘foreach’, ‘iterators’, ‘gap.datasets’, ‘plotly’, ‘Rdpack’, ‘shiny’, ‘plyr’, ‘doParallel’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘gap’, ‘ape’, ‘qgam’, ‘lme4’
#
#
# This is DHARMa 0.4.6. For overview type '?DHARMa'. For recent changes, type news(package = 'DHARMa')

# %%
adf.test(res)
kpss.test(res)
# --> data is non-stationary
# double-check with auto.arima()

starting_model <- auto.arima(res)
checkresiduals(starting_model)
# --> residuals need to be differenced once to become stationary
d=1
diff_res <- diff(res,1)
acf(diff_res)
# last significant lag at t=7  --> max grid search p-oder = 9
pacf(diff_res)
# last significant lat at t=25 --> max grid search q-oder = 27

test_df<- data.frame(matrix(nrow=(9*27),ncol = 5))
colnames(test_df)<- c("AICC","sum_nine","sum_all","p","q")
# Out:
# Warning message in adf.test(res):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  res
# Dickey-Fuller = -5.8978, Lag order = 12, p-value = 0.01
# alternative hypothesis: stationary
# 	KPSS Test for Level Stationarity
#
# data:  res
# KPSS Level = 0.5974, Truncation lag parameter = 8, p-value = 0.02287
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(3,1,1)
# Q* = 59.522, df = 6, p-value = 5.627e-11
#
# Model df: 4.   Total lags used: 10
# plot without title
# Plot with title “Series  diff_res”
# Plot with title “Series  diff_res”

# %%
###### ARIMA calculation ########
##Arima result gotten from existing work (github), so we skipped recalculating it

##load the results:
test_df <- read.csv("mid_ARIMA_results.csv")

test_df<- test_df[is.na(test_df$sum_all)==F,]
p_order <- test_df$p[test_df$sum_all==min(test_df$sum_all)]
q_order <- test_df$q[test_df$sum_all==min(test_df$sum_all)]


best_model_mid <- Arima(res, order = c(p_order, d, q_order))

save(best_model_mid,file="fit2.mid.Rdata")

# %%
### Add linear regressors to ARIMA ----

# First test within-group deviation from uniformity and homogeneity of variances
# of the seasonal regressors with scaled residuals from DHARMa package
simulationOutput <- simulateResiduals(fittedModel = model_final, plot = F)

# %%
# test weekdays

testCategorical(simulationOutput, catPred = MT_deterministic_data1$mon[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$tue[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$wed[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$thu[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$sat[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$we[1:2190])
# Out:
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.03145, p-value = 0.0487
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.043795, p-value = 0.5877
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.0487013 0.5876755
#
# $uniformity$p.value.cor
# [1] 0.09740261 0.58767551
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value Pr(>F)
# group    1   0.052 0.8197
#       2188
# plot without title
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.0308, p-value = 0.05681
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.064639, p-value = 0.1462
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.05680564 0.14619769
#
# $uniformity$p.value.cor
# [1] 0.1136113 0.1461977
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value Pr(>F)
# group    1  1.9749 0.1601
#       2188
# plot without title
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.031367, p-value = 0.04977
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.044179, p-value = 0.5743
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.04976696 0.57434063
#
# $uniformity$p.value.cor
# [1] 0.09953391 0.57434063
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value Pr(>F)
# group    1  0.0804 0.7768
#       2188
# plot without title
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.032416, p-value = 0.03872
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.03384, p-value = 0.866
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.03871824 0.86600571
#
# $uniformity$p.value.cor
# [1] 0.07743649 0.86600571
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value Pr(>F)
# group    1  0.3582 0.5496
#       2188
# plot without title
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.031367, p-value = 0.04977
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.044984, p-value = 0.5509
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.04976696 0.55091139
#
# $uniformity$p.value.cor
# [1] 0.09953391 0.55091139
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value Pr(>F)
# group    1  0.1278 0.7207
#       2188
# plot without title
# $uniformity
# $uniformity$details
# catPred: 0
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.037206, p-value = 0.03041
# alternative hypothesis: two-sided
#
# ------------------------------------------------------------
# catPred: 1
#
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  dd[x, ]
# D = 0.02728, p-value = 0.694
# alternative hypothesis: two-sided
#
#
# $uniformity$p.value
# [1] 0.03040899 0.69396941
#
# $uniformity$p.value.cor
# [1] 0.06081797 0.69396941
#
#
# $homogeneity
# Levene's Test for Homogeneity of Variance (center = median)
#         Df F value  Pr(>F)
# group    1   3.585 0.05844 .
#       2188
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# plot without title

# %%
# test month

testCategorical(simulationOutput, catPred = MT_deterministic_data1$jan[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$feb[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$mar[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$apr[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$mai[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$jun[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$jul[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$aug[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$sep[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$okt[1:2190])
testCategorical(simulationOutput, catPred = MT_deterministic_data1$nov[1:2190])
# Out:
# Error in testCategorical(simulationOutput, catPred = MT_deterministic_data1$jan[1:2190]): could not find function "testCategorical"
# Traceback:

# %%
# -> weekdays seem to be completely accounted for by the deterministic model
#    maybe adding the month as external predictors can improve the forecast

# Try all external predictors and check for significance

grid_model_reg <- Arima(res, order = c(p_order, d, q_order),xreg = as.matrix(MT_deterministic_data1[1:2190,c(18:28)]))
forecasted_arima_reg<-forecast(grid_model_reg, h=730, xreg = as.matrix(MT_deterministic_data1[2191:2920,c(18:28)]) ,biasadj=TRUE,bootstrap = TRUE)
plot(forecasted_arima_reg)
summary(grid_model_reg)
# Out:
# Warning message in sqrt(diag(x$var.coef)):
# “NaNs produced”
# Series: res
# Regression with ARIMA(4,1,16) errors
#
# Coefficients:
#          ar1      ar2      ar3      ar4      ma1     ma2      ma3     ma4
#       0.0095  -1.2484  -0.0367  -0.2637  -0.3922  1.2020  -0.5353  0.0776
# s.e.     NaN   0.4296      NaN   0.3965      NaN  0.5143      NaN  0.4961
#           ma5     ma6     ma7      ma8     ma9     ma10     ma11     ma12
#       -0.2778  -0.162  0.0413  -0.1142  0.1184  -0.0968  -0.0245  -0.0841
# s.e.   0.0635     NaN     NaN   0.0682  0.0529   0.0542   0.0632   0.0244
#          ma13     ma14     ma15    ma16        jan        feb       mar
#       -0.0145  -0.0436  -0.0083  0.0094  -190.1173  -360.8619  -45.3185
# s.e.      NaN   0.0488   0.0108  0.0351   110.7799   141.3343  157.2659
#            apr       mai       jun       jul       aug      sep       okt
#       318.2297  332.6766  329.4189  538.4639  667.0542  676.181  284.4887
# s.e.  170.8600  178.5293  179.3376  177.4646  172.9379  159.699  133.7729
#           nov
#       16.8285
# s.e.  98.0979
#
# sigma^2 = 89614:  log likelihood = -15571.75
# AIC=31207.5   AICc=31208.48   BIC=31389.62
#
# Training set error measures:
#                      ME     RMSE      MAE       MPE     MAPE      MASE
# Training set -0.4389605 297.1605 212.6097 -165.0932 391.3319 0.9112535
#                      ACF1
# Training set 0.0001366418
# Plot with title “Forecasts from Regression with ARIMA(4,1,16) errors”

# %%
# Compare with normal ARIMA forecast and GRU1 forecast

forecasted_arima<-forecast(best_model_mid, h=730,biasadj=TRUE,bootstrap = TRUE)

res_forecasted <- forecasted_arima$mean
res_forecasted_gru <-MT_deterministic_data1$gru[2191:2920]
res_forecasted_reg <- forecasted_arima_reg$mean

res_sum_arima <- sum(abs(MT_deterministic_data1$target_residuals[2191:2920] - res_forecasted))
res_sum_arima
res_sum_arima_gru <- sum(abs(MT_deterministic_data1$target_residuals[2191:2920] - res_forecasted_gru))
res_sum_arima_gru
res_sum_arima_reg <- sum(abs(MT_deterministic_data1$target_residuals[2191:2920] - res_forecasted_reg))
res_sum_arima_reg
# Out:
# [1] 338468.7
# [1] 304274.7
# [1] 337314.5

# %%
# --> GRU and ARIMA without external regressors still have a better forecast accuracy/lower residual sum
# Check the residual structure visually and add a yearly sinus

MT_deterministic_data1$index <- 1:nrow(MT_deterministic_data1)

t=seq(0.0172,pi*2,(pi*(2/365)))
yearly_sin <- sin(t)
plot(t,yearly_sin,type="l", xlab="time", ylab="Sine wave")
MT_deterministic_data1$sin <- yearly_sin *2000

library(ggplot2)
res_structure <- ggplot(MT_deterministic_data1[1:2920,])+geom_line(aes(index,target_residuals,color='residuals'))+
                 geom_line(aes(index,sin))
res_structure
# Out:
# plot without title
# plot without title

# %%
## --> summer time seems to still show a recurring pattern as well as the start of the year
#     summer, autumn and spring month as well as january are added step-wise to see if forecasting accuracy can
#     be improved.

best_model_mid_with_reg <- Arima(res, order = c(p_order, d, q_order),xreg = as.matrix(MT_deterministic_data1[1:2190,c(18,22:27)]))
forecasted_arima_reg2<-forecast(best_model_mid_with_reg, h=730, xreg = as.matrix(MT_deterministic_data1[2191:2920,c(18,22:27)]) ,biasadj=TRUE,bootstrap = TRUE)

res_forecasted_reg <- forecasted_arima_reg2$mean
res_sum_arima_reg <- sum(abs(MT_deterministic_data1$target_residuals[2191:2920] - res_forecasted_reg))
res_sum_arima_reg
res_sum_arima_reg/sum(abs(MT_deterministic_data1$target_residuals[2191:2920]))
res_sum_arima_gru/sum(abs(MT_deterministic_data1$target_residuals[2191:2920]))
# Out:
# [1] 291709.2
# [1] 0.9276718
# [1] 0.9676314

# %%
# Check forecast visually
MT_deterministic_data1$arima_gru <- c(best_model_mid_with_reg$fitted,(res_forecasted_reg+res_forecasted_gru))

res_comparism <- ggplot(MT_deterministic_data1[2191:2920,])+geom_line(aes(index,target_residuals,color='residuals'),lwd=1.2)+
  geom_line(aes(index, res_forecasted,color="ARIMA"),lwd=1.2)+geom_line(aes(index, res_forecasted_reg,color= "ARIMA /w reg"),lwd=1.2)+
  geom_line(aes(index,gru,color="GRU2"),lwd=1.2)+ geom_line(aes(index,arima_gru
                                                                  ,color="ARIMA+GRU2"),lwd=1.2)

res_comparism
# Out:
# plot without title

# %%
# Save Arima model with regressors

save(best_model_mid_with_reg,file = "final_ARIMA_mid.Rdata")

# %%
###### Save all model results ########

midterm_model_results <- MT_deterministic_data1[,c(1:4,37:39,41:43)]
midterm_model_results$stoch <- c(best_model_mid_with_reg$fitted,res_forecasted_gru)
midterm_model_results$full_model <- midterm_model_results$lm_pred+midterm_model_results$stoch
midterm_model_results$res_full_model <- midterm_model_results$mid_load -midterm_model_results$full_model


write.csv(midterm_model_results,"midterm_model_results.csv",row.names = F)

# %%
###### Plot results ########
# Install the patchwork package
install.packages("patchwork")

# Load the patchwork package
library(patchwork)
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# load local library for plotting
source('ggplot_theme_Publication-2.R')

# %%
# Install the ggthemes package
install.packages("ggthemes")

# Load the ggthemes package
library(ggthemes)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
midterm_model_results <- read.csv("midterm_model_results.csv")


MTplot_overview <- ggplot(midterm_model_results)+geom_line(aes(index,mid_load,color="actual"),lwd=1.3)+
  geom_line(aes(index,lm_pred,color='fitted'),linetype=2,lwd=1.3)+
  geom_vline(xintercept=2190,linetype = 2)+
  xlab("\n Day of year") + ylab("MW\n")+
  ggtitle('Mid-term model predictions')+
  theme_Publication()+ theme(legend.title = element_blank())+
  theme(axis.title=element_text(size=26))+
  theme(legend.text=element_text(size=26))+
  theme(axis.text=element_text(size=23))+
  theme(plot.title = element_text(size=34))+
  scale_x_continuous(breaks=c(0,730,1460 , 2190), labels=c(2013,2015,2017,2019))

MTplot_overview

ggsave(file="MTplot_overview.png", plot=MTplot_overview, width=12, height=8)
# Out:
# plot without title

# %%
# Residual plots

MTres1<-ggplot(midterm_model_results[0:2190,]) + geom_line(aes(x = index, y =target_residuals ),lwd=1.3)+
  ggtitle(label = "Residual Plots\n") +theme_Publication()+
  ylab("MW")+xlab("Day")+
  theme(axis.title=element_text(size=26))+
  theme(legend.text=element_text(size=26))+
  theme(axis.text=element_text(size=23))+
  theme(plot.title = element_text(size=34))+
  scale_x_continuous(breaks=c(0,730,1460 , 2190), labels=c(2013,2015,2017,2019))

MTres1

MTres2<-ggAcf(midterm_model_results$target_residuals[1:2190], lag.max = 48)+ theme_Publication() +ggtitle(element_blank())+
  theme(axis.title=element_text(size=26))+
  theme(legend.text=element_text(size=26))+
  theme(axis.text=element_text(size=23))+
  theme(plot.title = element_text(size=34))

MTres2

MTres3<-ggplot(midterm_model_results[1:2190,], aes(x = target_residuals))+geom_histogram(aes(y = ..density..),binwidth = 100) +
  geom_density(color="red",lwd=1.3)+
  theme_Publication()+
  ylab("Density")+xlab("MW")+
  theme(axis.title=element_text(size=26))+
  theme(legend.text=element_text(size=26))+
  theme(axis.text=element_text(size=23))+
  theme(plot.title = element_text(size=34))

MTres3
# Out:
# plot without title
# Warning message:
# “The dot-dot notation (`..density..`) was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(density)` instead.”
# plot without title
# plot without title

# %%
## Arrange residual plots

MTresiduals<-MTres1 /(MTres2+MTres3)
MTresiduals

ggsave(file="MTplot_residuals2.png", plot=MTresiduals, width=12, height=8)
# Out:
# plot without title
